# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# Data has already been merged (see 'data story so far.docx'). Read CSV and see dataframe.

# %%
data = pd.read_csv("reduced_2019.csv")

data_df = data

data_df.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# 1  2019-01  -1.850056  52.591108     On or near Walsall Road  E01009417
# 2  2019-01  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 3  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 4  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
#
#          LSOA name District code (2019) District name (2019)  \
# 0  Birmingham 001A            E08000025           Birmingham
# 1  Birmingham 001A            E08000025           Birmingham
# 2  Birmingham 001A            E08000025           Birmingham
# 3  Birmingham 001A            E08000025           Birmingham
# 4  Birmingham 001A            E08000025           Birmingham
#
#                     Description  Population  \
# 0  Urban with Major Conurbation   1073045.0
# 1  Urban with Major Conurbation   1073045.0
# 2  Urban with Major Conurbation   1073045.0
# 3  Urban with Major Conurbation   1073045.0
# 4  Urban with Major Conurbation   1073045.0
#
#    Index of Multiple Deprivation (IMD)  Income deprivation- Average score   \
# 0                                    7                               0.222
# 1                                    7                               0.222
# 2                                    7                               0.222
# 3                                    7                               0.222
# 4                                    7                               0.222
#
#    Income deprivation - Rank of average score   \
# 0                                            7
# 1                                            7
# 2                                            7
# 3                                            7
# 4                                            7
#
#    Income - Rank of proportion of LSOAs in most deprived 10% nationally
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# Viewing shape and contents of data.

# %%
data_df.shape
# Out:
# (296032, 17)

# %%
data_df.columns
# Out:
# Index(['Crime ID', 'Crime type', 'Last outcome category', 'Month', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name',
#        'District code (2019)', 'District name (2019)', 'Description',
#        'Population', 'Index of Multiple Deprivation (IMD)',
#        'Income deprivation- Average score ',
#        'Income deprivation - Rank of average score ',
#        'Income - Rank of proportion of LSOAs in most deprived 10% nationally '],
#       dtype='object')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296032 entries, 0 to 296031
# Data columns (total 17 columns):
#  #   Column                                                                 Non-Null Count   Dtype
# ---  ------                                                                 --------------   -----
#  0   Crime ID                                                               259543 non-null  object
#  1   Crime type                                                             296032 non-null  object
#  2   Last outcome category                                                  259543 non-null  object
#  3   Month                                                                  296032 non-null  object
#  4   Longitude                                                              296032 non-null  float64
#  5   Latitude                                                               296032 non-null  float64
#  6   Location                                                               296032 non-null  object
#  7   LSOA code                                                              296032 non-null  object
#  8   LSOA name                                                              296032 non-null  object
#  9   District code (2019)                                                   296032 non-null  object
#  10  District name (2019)                                                   296032 non-null  object
#  11  Description                                                            296032 non-null  object
#  12  Population                                                             296032 non-null  float64
#  13  Index of Multiple Deprivation (IMD)                                    296032 non-null  int64
#  14  Income deprivation- Average score                                      296032 non-null  float64
#  15  Income deprivation - Rank of average score                             296032 non-null  int64
#  16  Income - Rank of proportion of LSOAs in most deprived 10% nationally   296032 non-null  int64
# dtypes: float64(4), int64(3), object(10)
# memory usage: 38.4+ MB

# %%
data_df.duplicated()
boolean_series_of_duplicates = data_df.duplicated()
len(data_df.loc[boolean_series_of_duplicates, :])
# Out:
# 8649

# %%
data_df.loc[boolean_series_of_duplicates, :]
# Out:
#        Crime ID             Crime type Last outcome category    Month  \
# 67          NaN  Anti-social behaviour                   NaN  2019-07
# 68          NaN  Anti-social behaviour                   NaN  2019-07
# 159         NaN  Anti-social behaviour                   NaN  2019-12
# 160         NaN  Anti-social behaviour                   NaN  2019-12
# 199         NaN  Anti-social behaviour                   NaN  2019-07
# ...         ...                    ...                   ...      ...
# 295786      NaN  Anti-social behaviour                   NaN  2019-02
# 295788      NaN  Anti-social behaviour                   NaN  2019-02
# 295789      NaN  Anti-social behaviour                   NaN  2019-02
# 295818      NaN  Anti-social behaviour                   NaN  2019-06
# 295863      NaN  Anti-social behaviour                   NaN  2019-12
#
#         Longitude   Latitude                           Location  LSOA code  \
# 67      -1.840641  52.598270       On or near Badgers Bank Road  E01009418
# 68      -1.845780  52.593827              On or near Hook Drive  E01009418
# 159     -1.849079  52.595980         On or near Blackberry Lane  E01009419
# 160     -1.849079  52.595980         On or near Blackberry Lane  E01009419
# 199     -1.843092  52.602471             On or near Moore Close  E01009433
# ...           ...        ...                                ...        ...
# 295786  -2.156332  52.610149              On or near Green Lane  E01010545
# 295788  -2.150734  52.605472  On or near Sports/Recreation Area  E01010545
# 295789  -2.150734  52.605472  On or near Sports/Recreation Area  E01010545
# 295818  -2.156332  52.610149              On or near Green Lane  E01010545
# 295863  -2.151333  52.607854            On or near Kestrel Rise  E01010545
#
#                  LSOA name District code (2019) District name (2019)  \
# 67         Birmingham 001B            E08000025           Birmingham
# 68         Birmingham 001B            E08000025           Birmingham
# 159        Birmingham 001C            E08000025           Birmingham
# 160        Birmingham 001C            E08000025           Birmingham
# 199        Birmingham 001D            E08000025           Birmingham
# ...                    ...                  ...                  ...
# 295786  Wolverhampton 009E            E08000031        Wolverhampton
# 295788  Wolverhampton 009E            E08000031        Wolverhampton
# 295789  Wolverhampton 009E            E08000031        Wolverhampton
# 295818  Wolverhampton 009E            E08000031        Wolverhampton
# 295863  Wolverhampton 009E            E08000031        Wolverhampton
#
#                          Description  Population  \
# 67      Urban with Major Conurbation   1073045.0
# 68      Urban with Major Conurbation   1073045.0
# 159     Urban with Major Conurbation   1073045.0
# 160     Urban with Major Conurbation   1073045.0
# 199     Urban with Major Conurbation   1073045.0
# ...                              ...         ...
# 295786  Urban with Major Conurbation    249470.0
# 295788  Urban with Major Conurbation    249470.0
# 295789  Urban with Major Conurbation    249470.0
# 295818  Urban with Major Conurbation    249470.0
# 295863  Urban with Major Conurbation    249470.0
#
#         Index of Multiple Deprivation (IMD)  \
# 67                                        5
# 68                                        5
# 159                                       6
# 160                                       6
# 199                                       9
# ...                                     ...
# 295786                                    7
# 295788                                    7
# 295789                                    7
# 295818                                    7
# 295863                                    7
#
#         Income deprivation- Average score   \
# 67                                   0.222
# 68                                   0.222
# 159                                  0.222
# 160                                  0.222
# 199                                  0.222
# ...                                    ...
# 295786                               0.211
# 295788                               0.211
# 295789                               0.211
# 295818                               0.211
# 295863                               0.211
#
#         Income deprivation - Rank of average score   \
# 67                                                7
# 68                                                7
# 159                                               7
# 160                                               7
# 199                                               7
# ...                                             ...
# 295786                                           11
# 295788                                           11
# 295789                                           11
# 295818                                           11
# 295863                                           11
#
#         Income - Rank of proportion of LSOAs in most deprived 10% nationally
# 67                                                      5
# 68                                                      5
# 159                                                     5
# 160                                                     5
# 199                                                     5
# ...                                                   ...
# 295786                                                 14
# 295788                                                 14
# 295789                                                 14
# 295818                                                 14
# 295863                                                 14
#
# [8649 rows x 17 columns]

# %% [markdown]
# We investigated the duplicates and found that the abive number was the number of crime IDs that had null values in similar locations. They also tended to fall into the crime type of anti-social behaviour.

# %%
data_df.isnull().sum()
# Out:
# Crime ID                                                                 36489
# Crime type                                                                   0
# Last outcome category                                                    36489
# Month                                                                        0
# Longitude                                                                    0
# Latitude                                                                     0
# Location                                                                     0
# LSOA code                                                                    0
# LSOA name                                                                    0
# District code (2019)                                                         0
# District name (2019)                                                         0
# Description                                                                  0
# Population                                                                   0
# Index of Multiple Deprivation (IMD)                                          0
# Income deprivation- Average score                                            0
# Income deprivation - Rank of average score                                   0
# Income - Rank of proportion of LSOAs in most deprived 10% nationally         0
# dtype: int64

# %% [markdown]
# The last outcome column shows many null values, we have decided to change this to 'No outcome recorded' rather than leave it blank.

# %%
# Fill in missing values in 'last outcome category'
data_df["Last outcome category"] = data_df["Last outcome category"].fillna('No outcome recorded')

# %% [markdown]
# ## Filter West Midlands data

# %% [markdown]
# We only want the data for the follwing districts: Birmingham, Coventry, Dudley, Sandwell, Solihull, Walsall, Wolverhampton. We will then filter this data into a new West_Midlands_df

# %%
West_midlands_df = data_df[(data_df["District name (2019)"]=="Birmingham")|(data_df["District name (2019)"]=="Coventry")|(data_df["District name (2019)"]=="Dudley")|(data_df["District name (2019)"]=="Sandwell")|(data_df["District name (2019)"]=="Solihull")|(data_df["District name (2019)"]=="Walsall")|(data_df["District name (2019)"]=="Wolverhampton")]

West_midlands_df.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# 1  2019-01  -1.850056  52.591108     On or near Walsall Road  E01009417
# 2  2019-01  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 3  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 4  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
#
#          LSOA name District code (2019) District name (2019)  \
# 0  Birmingham 001A            E08000025           Birmingham
# 1  Birmingham 001A            E08000025           Birmingham
# 2  Birmingham 001A            E08000025           Birmingham
# 3  Birmingham 001A            E08000025           Birmingham
# 4  Birmingham 001A            E08000025           Birmingham
#
#                     Description  Population  \
# 0  Urban with Major Conurbation   1073045.0
# 1  Urban with Major Conurbation   1073045.0
# 2  Urban with Major Conurbation   1073045.0
# 3  Urban with Major Conurbation   1073045.0
# 4  Urban with Major Conurbation   1073045.0
#
#    Index of Multiple Deprivation (IMD)  Income deprivation- Average score   \
# 0                                    7                               0.222
# 1                                    7                               0.222
# 2                                    7                               0.222
# 3                                    7                               0.222
# 4                                    7                               0.222
#
#    Income deprivation - Rank of average score   \
# 0                                            7
# 1                                            7
# 2                                            7
# 3                                            7
# 4                                            7
#
#    Income - Rank of proportion of LSOAs in most deprived 10% nationally
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5

# %%
West_midlands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295541 entries, 0 to 295871
# Data columns (total 17 columns):
#  #   Column                                                                 Non-Null Count   Dtype
# ---  ------                                                                 --------------   -----
#  0   Crime ID                                                               259087 non-null  object
#  1   Crime type                                                             295541 non-null  object
#  2   Last outcome category                                                  295541 non-null  object
#  3   Month                                                                  295541 non-null  object
#  4   Longitude                                                              295541 non-null  float64
#  5   Latitude                                                               295541 non-null  float64
#  6   Location                                                               295541 non-null  object
#  7   LSOA code                                                              295541 non-null  object
#  8   LSOA name                                                              295541 non-null  object
#  9   District code (2019)                                                   295541 non-null  object
#  10  District name (2019)                                                   295541 non-null  object
#  11  Description                                                            295541 non-null  object
#  12  Population                                                             295541 non-null  float64
#  13  Index of Multiple Deprivation (IMD)                                    295541 non-null  int64
#  14  Income deprivation- Average score                                      295541 non-null  float64
#  15  Income deprivation - Rank of average score                             295541 non-null  int64
#  16  Income - Rank of proportion of LSOAs in most deprived 10% nationally   295541 non-null  int64
# dtypes: float64(4), int64(3), object(10)
# memory usage: 40.6+ MB

# %%
# Fill in missing values in 'Crime ID'
West_midlands_df["Crime ID"] = West_midlands_df["Crime ID"].fillna('No ID recorded')
# Out:
# C:\Users\gcwhi\AppData\Local\Temp/ipykernel_27628/3972491802.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   West_midlands_df["Crime ID"] = West_midlands_df["Crime ID"].fillna('No ID recorded')

# %%
West_midlands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295541 entries, 0 to 295871
# Data columns (total 17 columns):
#  #   Column                                                                 Non-Null Count   Dtype
# ---  ------                                                                 --------------   -----
#  0   Crime ID                                                               295541 non-null  object
#  1   Crime type                                                             295541 non-null  object
#  2   Last outcome category                                                  295541 non-null  object
#  3   Month                                                                  295541 non-null  object
#  4   Longitude                                                              295541 non-null  float64
#  5   Latitude                                                               295541 non-null  float64
#  6   Location                                                               295541 non-null  object
#  7   LSOA code                                                              295541 non-null  object
#  8   LSOA name                                                              295541 non-null  object
#  9   District code (2019)                                                   295541 non-null  object
#  10  District name (2019)                                                   295541 non-null  object
#  11  Description                                                            295541 non-null  object
#  12  Population                                                             295541 non-null  float64
#  13  Index of Multiple Deprivation (IMD)                                    295541 non-null  int64
#  14  Income deprivation- Average score                                      295541 non-null  float64
#  15  Income deprivation - Rank of average score                             295541 non-null  int64
#  16  Income - Rank of proportion of LSOAs in most deprived 10% nationally   295541 non-null  int64
# dtypes: float64(4), int64(3), object(10)
# memory usage: 40.6+ MB

# %%
West_midlands_df.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# 1  2019-01  -1.850056  52.591108     On or near Walsall Road  E01009417
# 2  2019-01  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 3  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 4  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
#
#          LSOA name District code (2019) District name (2019)  \
# 0  Birmingham 001A            E08000025           Birmingham
# 1  Birmingham 001A            E08000025           Birmingham
# 2  Birmingham 001A            E08000025           Birmingham
# 3  Birmingham 001A            E08000025           Birmingham
# 4  Birmingham 001A            E08000025           Birmingham
#
#                     Description  Population  \
# 0  Urban with Major Conurbation   1073045.0
# 1  Urban with Major Conurbation   1073045.0
# 2  Urban with Major Conurbation   1073045.0
# 3  Urban with Major Conurbation   1073045.0
# 4  Urban with Major Conurbation   1073045.0
#
#    Index of Multiple Deprivation (IMD)  Income deprivation- Average score   \
# 0                                    7                               0.222
# 1                                    7                               0.222
# 2                                    7                               0.222
# 3                                    7                               0.222
# 4                                    7                               0.222
#
#    Income deprivation - Rank of average score   \
# 0                                            7
# 1                                            7
# 2                                            7
# 3                                            7
# 4                                            7
#
#    Income - Rank of proportion of LSOAs in most deprived 10% nationally
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5

# %%
West_midlands_df.to_csv('clean_2019.csv', index=False)

# %%
lidd = pd.read_excel("localincomedeprivationdata.xlsx", engine='openpyxl')

# %%
lidd.head()
# Out:
#   LSOA code (2011) LSOA name (2011) Local Authority District code (2019)  \
# 0        E01031338        Adur 002A                            E07000223
# 1        E01031339        Adur 002B                            E07000223
# 2        E01031340        Adur 002C                            E07000223
# 3        E01031341        Adur 008A                            E07000223
# 4        E01031342        Adur 008B                            E07000223
#
#   Local Authority District name (2019)  \
# 0                                 Adur
# 1                                 Adur
# 2                                 Adur
# 3                                 Adur
# 4                                 Adur
#
#    Overall Index of Multiple Deprivation (IMD) Score  \
# 0                                              5.518
# 1                                              6.186
# 2                                              5.213
# 3                                             38.777
# 4                                             16.050
#
#    Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)  \
# 0                                              30006
# 1                                              29228
# 2                                              30309
# 3                                               4639
# 4                                              17896
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Income Score (rate)  Income Rank (where 1 is most deprived)  \
# 0                0.054                                   25262
# 1                0.052                                   25709
# 2                0.027                                   31386
# 3                0.237                                    4645
# 4                0.083                                   19015
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  8
# 1                                                  8
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Total population: mid 2015 (excluding prisoners)  \
# 0                                              1159
# 1                                              1200
# 2                                              1464
# 3                                              1371
# 4                                              1731
#
#    Dependent Children aged 0-15: mid 2015 (excluding prisoners)  \
# 0                                                202
# 1                                                229
# 2                                                241
# 3                                                239
# 4                                                235
#
#    Population aged 16-59: mid 2015 (excluding prisoners)  \
# 0                                                603
# 1                                                653
# 2                                                691
# 3                                                775
# 4                                                760
#
#    Older population aged 60 and over: mid 2015 (excluding prisoners)  \
# 0                                                354
# 1                                                318
# 2                                                532
# 3                                                357
# 4                                                736
#
#    Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners)
# 0                                                618
# 1                                                664
# 2                                                707
# 3                                                785
# 4                                                768

# %%
lidd = lidd.rename(columns={"Overall Index of Multiple Deprivation (IMD) Score":"LSOA IMD Score"})

# %%
lidd.head()
# Out:
#   LSOA code (2011) LSOA name (2011) Local Authority District code (2019)  \
# 0        E01031338        Adur 002A                            E07000223
# 1        E01031339        Adur 002B                            E07000223
# 2        E01031340        Adur 002C                            E07000223
# 3        E01031341        Adur 008A                            E07000223
# 4        E01031342        Adur 008B                            E07000223
#
#   Local Authority District name (2019)  LSOA IMD Score  \
# 0                                 Adur           5.518
# 1                                 Adur           6.186
# 2                                 Adur           5.213
# 3                                 Adur          38.777
# 4                                 Adur          16.050
#
#    Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)  \
# 0                                              30006
# 1                                              29228
# 2                                              30309
# 3                                               4639
# 4                                              17896
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Income Score (rate)  Income Rank (where 1 is most deprived)  \
# 0                0.054                                   25262
# 1                0.052                                   25709
# 2                0.027                                   31386
# 3                0.237                                    4645
# 4                0.083                                   19015
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  8
# 1                                                  8
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Total population: mid 2015 (excluding prisoners)  \
# 0                                              1159
# 1                                              1200
# 2                                              1464
# 3                                              1371
# 4                                              1731
#
#    Dependent Children aged 0-15: mid 2015 (excluding prisoners)  \
# 0                                                202
# 1                                                229
# 2                                                241
# 3                                                239
# 4                                                235
#
#    Population aged 16-59: mid 2015 (excluding prisoners)  \
# 0                                                603
# 1                                                653
# 2                                                691
# 3                                                775
# 4                                                760
#
#    Older population aged 60 and over: mid 2015 (excluding prisoners)  \
# 0                                                354
# 1                                                318
# 2                                                532
# 3                                                357
# 4                                                736
#
#    Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners)
# 0                                                618
# 1                                                664
# 2                                                707
# 3                                                785
# 4                                                768

# %%
lidd = lidd.rename(columns={"Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)":"LSOA IMD Rank"})

# %%
lidd.head()
# Out:
#   LSOA code (2011) LSOA name (2011) Local Authority District code (2019)  \
# 0        E01031338        Adur 002A                            E07000223
# 1        E01031339        Adur 002B                            E07000223
# 2        E01031340        Adur 002C                            E07000223
# 3        E01031341        Adur 008A                            E07000223
# 4        E01031342        Adur 008B                            E07000223
#
#   Local Authority District name (2019)  LSOA IMD Score  LSOA IMD Rank  \
# 0                                 Adur           5.518          30006
# 1                                 Adur           6.186          29228
# 2                                 Adur           5.213          30309
# 3                                 Adur          38.777           4639
# 4                                 Adur          16.050          17896
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Income Score (rate)  Income Rank (where 1 is most deprived)  \
# 0                0.054                                   25262
# 1                0.052                                   25709
# 2                0.027                                   31386
# 3                0.237                                    4645
# 4                0.083                                   19015
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  8
# 1                                                  8
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Total population: mid 2015 (excluding prisoners)  \
# 0                                              1159
# 1                                              1200
# 2                                              1464
# 3                                              1371
# 4                                              1731
#
#    Dependent Children aged 0-15: mid 2015 (excluding prisoners)  \
# 0                                                202
# 1                                                229
# 2                                                241
# 3                                                239
# 4                                                235
#
#    Population aged 16-59: mid 2015 (excluding prisoners)  \
# 0                                                603
# 1                                                653
# 2                                                691
# 3                                                775
# 4                                                760
#
#    Older population aged 60 and over: mid 2015 (excluding prisoners)  \
# 0                                                354
# 1                                                318
# 2                                                532
# 3                                                357
# 4                                                736
#
#    Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners)
# 0                                                618
# 1                                                664
# 2                                                707
# 3                                                785
# 4                                                768

# %%
lidd = lidd.rename(columns={"Income Rank (where 1 is most deprived)":"LSOA Income Rank"})

# %%
lidd.head()
# Out:
#   LSOA code (2011) LSOA name (2011) Local Authority District code (2019)  \
# 0        E01031338        Adur 002A                            E07000223
# 1        E01031339        Adur 002B                            E07000223
# 2        E01031340        Adur 002C                            E07000223
# 3        E01031341        Adur 008A                            E07000223
# 4        E01031342        Adur 008B                            E07000223
#
#   Local Authority District name (2019)  LSOA IMD Score  LSOA IMD Rank  \
# 0                                 Adur           5.518          30006
# 1                                 Adur           6.186          29228
# 2                                 Adur           5.213          30309
# 3                                 Adur          38.777           4639
# 4                                 Adur          16.050          17896
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Income Score (rate)  LSOA Income Rank  \
# 0                0.054             25262
# 1                0.052             25709
# 2                0.027             31386
# 3                0.237              4645
# 4                0.083             19015
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  8
# 1                                                  8
# 2                                                 10
# 3                                                  2
# 4                                                  6
#
#    Total population: mid 2015 (excluding prisoners)  \
# 0                                              1159
# 1                                              1200
# 2                                              1464
# 3                                              1371
# 4                                              1731
#
#    Dependent Children aged 0-15: mid 2015 (excluding prisoners)  \
# 0                                                202
# 1                                                229
# 2                                                241
# 3                                                239
# 4                                                235
#
#    Population aged 16-59: mid 2015 (excluding prisoners)  \
# 0                                                603
# 1                                                653
# 2                                                691
# 3                                                775
# 4                                                760
#
#    Older population aged 60 and over: mid 2015 (excluding prisoners)  \
# 0                                                354
# 1                                                318
# 2                                                532
# 3                                                357
# 4                                                736
#
#    Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners)
# 0                                                618
# 1                                                664
# 2                                                707
# 3                                                785
# 4                                                768

# %%
del lidd['LSOA name (2011)']
del lidd['Local Authority District code (2019)']
del lidd['Local Authority District name (2019)']
del lidd['Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)']
del lidd['Income Score (rate)']
del lidd['Income Decile (where 1 is most deprived 10% of LSOAs)']
del lidd['Total population: mid 2015 (excluding prisoners)']
del lidd['Dependent Children aged 0-15: mid 2015 (excluding prisoners)']
del lidd['Population aged 16-59: mid 2015 (excluding prisoners)']
del lidd['Older population aged 60 and over: mid 2015 (excluding prisoners)']
del lidd['Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners) ']

# %%
lidd.head()
# Out:
#   LSOA code (2011)  LSOA IMD Score  LSOA IMD Rank  LSOA Income Rank
# 0        E01031338           5.518          30006             25262
# 1        E01031339           6.186          29228             25709
# 2        E01031340           5.213          30309             31386
# 3        E01031341          38.777           4639              4645
# 4        E01031342          16.050          17896             19015

# %%
lidd = lidd.rename(columns={"Local Authority District code (2019)":"LSOA code"})
lidd.head()
# Out:
#    LSOA code  LSOA IMD Score  LSOA IMD Rank  LSOA Income Rank
# 0  E01031338           5.518          30006             25262
# 1  E01031339           6.186          29228             25709
# 2  E01031340           5.213          30309             31386
# 3  E01031341          38.777           4639              4645
# 4  E01031342          16.050          17896             19015

# %%
West_midlands_df1 = pd.merge(West_midlands_df, lidd, on = "LSOA code")
West_midlands_df1.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# 1  2019-01  -1.850056  52.591108     On or near Walsall Road  E01009417
# 2  2019-01  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 3  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 4  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
#
#          LSOA name District code (2019) District name (2019)  \
# 0  Birmingham 001A            E08000025           Birmingham
# 1  Birmingham 001A            E08000025           Birmingham
# 2  Birmingham 001A            E08000025           Birmingham
# 3  Birmingham 001A            E08000025           Birmingham
# 4  Birmingham 001A            E08000025           Birmingham
#
#                     Description  Population  \
# 0  Urban with Major Conurbation   1073045.0
# 1  Urban with Major Conurbation   1073045.0
# 2  Urban with Major Conurbation   1073045.0
# 3  Urban with Major Conurbation   1073045.0
# 4  Urban with Major Conurbation   1073045.0
#
#    Index of Multiple Deprivation (IMD)  Income deprivation- Average score   \
# 0                                    7                               0.222
# 1                                    7                               0.222
# 2                                    7                               0.222
# 3                                    7                               0.222
# 4                                    7                               0.222
#
#    Income deprivation - Rank of average score   \
# 0                                            7
# 1                                            7
# 2                                            7
# 3                                            7
# 4                                            7
#
#    Income - Rank of proportion of LSOAs in most deprived 10% nationally   \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    LSOA IMD Score  LSOA IMD Rank  LSOA Income Rank
# 0          12.652          21433             18278
# 1          12.652          21433             18278
# 2          12.652          21433             18278
# 3          12.652          21433             18278
# 4          12.652          21433             18278

# %%
West_midlands_df1.columns
# Out:
# Index(['Crime ID', 'Crime type', 'Last outcome category', 'Month', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name',
#        'District code (2019)', 'District name (2019)', 'Description',
#        'Population', 'Index of Multiple Deprivation (IMD)',
#        'Income deprivation- Average score ',
#        'Income deprivation - Rank of average score ',
#        'Income - Rank of proportion of LSOAs in most deprived 10% nationally ',
#        'LSOA IMD Score', 'LSOA IMD Rank', 'LSOA Income Rank'],
#       dtype='object')

# %%
West_midlands_df1 = West_midlands_df1.reindex(['Crime ID', 'Crime type', 'Last outcome category', 'Month', 'Longitude',
       'Latitude', 'Location', 'LSOA code', 'LSOA name','LSOA IMD Score', 'LSOA IMD Rank', 'LSOA Income Rank',
       'District code (2019)', 'District name (2019)', 'Description',
       'Population', 'Index of Multiple Deprivation (IMD)',
       'Income deprivation- Average score ',
       'Income deprivation - Rank of average score ',
       'Income - Rank of proportion of LSOAs in most deprived 10% nationally '
       ], axis=1)

# %%
West_midlands_df1.head()
# Out:
#                                             Crime ID  \
# 0  b0854078f33cc4e2ecd7353c40d3a03120063e7d39134b...
# 1  b48f19d1ca24bd7e1ef53952c1472314c1af57240df6d5...
# 2  2ea61ee241faeac03c5595efc0e3d838d79f20f5831f24...
# 3  0fd56c14bbd052c45e7e9abc1c182c5201e5664a61dc03...
# 4  cadab8dbc07947f5db64c9c0206077758cbbad346611cc...
#
#                   Crime type                          Last outcome category  \
# 0                   Burglary  Investigation complete; no suspect identified
# 1                Other theft  Investigation complete; no suspect identified
# 2               Public order  Investigation complete; no suspect identified
# 3  Criminal damage and arson  Investigation complete; no suspect identified
# 4  Criminal damage and arson  Investigation complete; no suspect identified
#
#      Month  Longitude   Latitude                    Location  LSOA code  \
# 0  2019-01  -1.850519  52.589275       On or near Crown Lane  E01009417
# 1  2019-01  -1.850056  52.591108     On or near Walsall Road  E01009417
# 2  2019-01  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 3  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
# 4  2019-02  -1.850772  52.588691  On or near Seymour Gardens  E01009417
#
#          LSOA name  LSOA IMD Score  LSOA IMD Rank  LSOA Income Rank  \
# 0  Birmingham 001A          12.652          21433             18278
# 1  Birmingham 001A          12.652          21433             18278
# 2  Birmingham 001A          12.652          21433             18278
# 3  Birmingham 001A          12.652          21433             18278
# 4  Birmingham 001A          12.652          21433             18278
#
#   District code (2019) District name (2019)                   Description  \
# 0            E08000025           Birmingham  Urban with Major Conurbation
# 1            E08000025           Birmingham  Urban with Major Conurbation
# 2            E08000025           Birmingham  Urban with Major Conurbation
# 3            E08000025           Birmingham  Urban with Major Conurbation
# 4            E08000025           Birmingham  Urban with Major Conurbation
#
#    Population  Index of Multiple Deprivation (IMD)  \
# 0   1073045.0                                    7
# 1   1073045.0                                    7
# 2   1073045.0                                    7
# 3   1073045.0                                    7
# 4   1073045.0                                    7
#
#    Income deprivation- Average score   \
# 0                               0.222
# 1                               0.222
# 2                               0.222
# 3                               0.222
# 4                               0.222
#
#    Income deprivation - Rank of average score   \
# 0                                            7
# 1                                            7
# 2                                            7
# 3                                            7
# 4                                            7
#
#    Income - Rank of proportion of LSOAs in most deprived 10% nationally
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5

# %%
West_midlands_df1.to_csv('clean_2019_1.csv', index=False)
